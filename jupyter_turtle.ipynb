# %% [markdown]
# ## 🐢タートルグラフィックスを始めるための準備🐢
# 準備は簡単です！👇のコマンド入力欄(セルと呼びます)の左にある「▶」ボタンを押して実行してみましょう。
# すると白いキャンバスに緑のカメが表示されます。
# これで準備は完了です❗😽😽😽😽😽

# %%
#############################################################################################################
#👈にある再生ボタンをクリックして実行してください。そうすればタートルグラフィックスのための準備は完了です！#
#############################################################################################################
# %pip install ColabTurtle
from ColabTurtle.Turtle import *
initializeTurtle()
speed(1)
bgcolor('white')
pencolor('green')
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
#       <svg width="800" height="500">
#         <rect width="100%" height="100%" fill="white"/>
#         <line x1="400" y1="250" x2="400.0" y2="150.0" stroke-linecap="round" style="stroke:green;stroke-width:4"/><line x1="400.0" y1="150.0" x2="400.0" y2="50.0" stroke-linecap="round" style="stroke:green;stroke-width:4"/><line x1="400.0" y1="50.0" x2="500.0" y2="50.0" stroke-linecap="round" style="stroke:green;stroke-width:4"/><line x1="500.0" y1="50.0" x2="500.0" y2="150.0" stroke-linecap="round" style="stroke:green;stroke-width:4"/><line x1="500.0" y1="150.0" x2="400.0" y2="150.0" stroke-linecap="round" style="stroke:green;stroke-width:4"/><line x1="400.0" y1="150.0" x2="400.0" y2="50.0" stroke-linecap="round" style="stroke:green;stroke-width:4"/>
#         <g visibility=visible transform="rotate(360,400.0,50.0) translate(382.0, 32.0)">
# ...

# %% [markdown]
# かわいいカメさん！
# 🐢🐢🐢🐢🐢🐢🐢🐢🐢🐢🐢🐢🐢🐢🐢🐢🐢🐢🐢🐢🐢🐢🐢
# ちなみに実行はプログラム文を入力中に`Ctrl+Enter`(MacOSなら`Command+Enter`)でもできますよ！

# %% [markdown]
# ------
# ## 線を引いてみましょう
# 試しにカメさんに命令をしてみましょう。
# このカメは緑色のペンを持っています。「前へ進め！」と命令すれば白いキャンバスに緑の線を引きながら前に進んでくれるはずです。
# ですが、そもそもこのカメはキャンバスに筆を置いていません…😿
# なのでまず、`pendown()`と命令してみましょう。これは「ペンをキャンバスに置け！」という意味です。

# %%
##########################################
#👇にpendown()と入力して実行してみてください。
##########################################
pendown()

# %% [markdown]
# ------
# 何も変わりませんね、ペンを置いてもらっただけですからね😹
# さて、いよいよ線を引いてもらいましょう。引いてもらうためには「前へ進め！」と命令するんでしたね。
# その命令は`forward()`。カッコの中に数字をいれることで進む長さを自由に決めれます。
# 今回は100進んでもらいましょう。なので入力する命令は`forward(100)`です。

# %%
##########################################
#👇にforward(100)と入力して実行してみてください。
##########################################
forward(100)

# %% [markdown]
# カメが線を引いてくれました！すごい！🎉🎉🎉🎉🎉🎉
# …大したことないって？そんな事ないですよ。だってあなたは今コンピュータに命令するプログラミングを見事にやったんですから！
# プログラム文(命令文)を書いて、コンピュータに実行させる。
# それがプログラミングの基本の考え方です。
# この感覚、大事にしてください😼

# %% [markdown]
# ------
# ## 四角形を描いてみましょう
# このカメは回転させることができます。`right(90)`で「90度右に回れ！」です。
# その後`forward(100)`を命令すれば「┌」みたいな図形を描けるのがイメージできそうですか？
# …できない？大丈夫！
# 👇でプログラム文を書けばカメが書いてくれますよ！😽👍

# %%
##########################################
#👇に
# right(90)
# forward(100)
# と入力して実行してみてください。
##########################################
right(90)
forward(100)

# %% [markdown]
# 右に90度曲がって線を引く…これを繰り返せば四角形を描ける気がしませんか？
# 頑張って描いてみましょう！😸
# 描いてるうちに分からなくなったときは`home()`と命令すればカメが最初の位置に、
# `clear()` と命令すれば描いたものを真っ白にできますよ。

# %%
##########################################
#👇にプログラム文を入力して四角形を描いてみましょう
##########################################

# %%
##########################################
#リセットしたいときはこのセルを実行しましょう
##########################################
home()
clear()

# %% [markdown]
# ## 四角形ができましたか？
# さすが！あなたはたった数十分でコンピュータに何個も命令ができるようになったわけですね！
# めっちゃカッコいい❗❗😻😻😻😻
#
# # 今回はここまで！
# もっといろんなことを試したい？ここはいつでも自由に使えますよ！
